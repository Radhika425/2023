# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
df = pd.read_csv('/content/heart_disease.csv')

# %%
df.head()
# Out:
#     id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0  209  19.0   70.0  1.020  0.0  0.0       NaN    normal  notpresent
# 1  280  47.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 2   33  60.0  100.0  1.020  2.0  0.0  abnormal  abnormal  notpresent
# 3  210  59.0  100.0  1.015  4.0  2.0    normal    normal  notpresent
# 4   93  73.0  100.0  1.010  3.0  2.0  abnormal  abnormal     present
#
#            ba  ...  hemo  pcv      wc   rc  htn   dm  cad  appet  pe  ane
# 0  notpresent  ...  11.5  NaN  6900.0  NaN   no   no   no   good  no   no
# 1  notpresent  ...  13.3   52  8100.0  5.2   no   no   no   good  no   no
# 2  notpresent  ...  10.1   29     NaN  NaN  yes   no   no   poor  no   no
# 3  notpresent  ...   7.3   20  9800.0  3.9  yes  yes  yes   good  no  yes
# 4  notpresent  ...   9.2   30  7000.0  3.2  yes  yes  yes   poor  no   no
#
# [5 rows x 25 columns]

# %%
print(df.shape)
# Out:
# (120, 25)

# %%
print(df.columns)
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane'],
#       dtype='object')

# %%
df.describe()
# Out:
#                id         age          bp          sg         al          su  \
# count  120.000000  116.000000  117.000000  109.000000  109.00000  109.000000
# mean   191.500000   51.551724   77.435897    1.017339    1.00000    0.477064
# std    123.781184   16.494186   12.258273    0.005675    1.30526    1.159473
# min      0.000000    5.000000   50.000000    1.005000    0.00000    0.000000
# 25%     77.750000   42.000000   70.000000    1.015000    0.00000    0.000000
# 50%    180.500000   54.500000   80.000000    1.020000    0.00000    0.000000
# 75%    292.500000   63.000000   90.000000    1.020000    2.00000    0.000000
# max    396.000000   82.000000  110.000000    1.025000    4.00000    5.000000
#
#               bgr          bu          sc        sod         pot        hemo  \
# count  109.000000  115.000000  115.000000  100.00000  100.000000  107.000000
# mean   143.165138   58.447826    3.226957  138.11000    4.358000   12.514953
# std     83.641709   48.429293    5.500659    6.99624    0.856488    2.992658
# min     22.000000    1.500000    0.500000  111.00000    2.500000    4.800000
# 25%     95.000000   25.000000    0.900000  135.00000    3.700000   10.250000
# 50%    113.000000   46.000000    1.200000  139.00000    4.350000   12.600000
# 75%    141.000000   72.000000    3.050000  142.00000    4.900000   15.100000
# max    490.000000  235.000000   48.100000  150.00000    7.600000   17.800000
#
#                  wc         rc
# count     92.000000  83.000000
# mean    8518.478261   4.709639
# std     2563.691078   1.022624
# min     2600.000000   2.100000
# 25%     6775.000000   3.950000
# 50%     8300.000000   4.800000
# 75%     9900.000000   5.200000
# max    19100.000000   6.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      120 non-null    int64
#  1   age     116 non-null    float64
#  2   bp      117 non-null    float64
#  3   sg      109 non-null    float64
#  4   al      109 non-null    float64
#  5   su      109 non-null    float64
#  6   rbc     75 non-null     object
#  7   pc      105 non-null    object
#  8   pcc     120 non-null    object
#  9   ba      120 non-null    object
#  10  bgr     109 non-null    float64
#  11  bu      115 non-null    float64
#  12  sc      115 non-null    float64
#  13  sod     100 non-null    float64
#  14  pot     100 non-null    float64
#  15  hemo    107 non-null    float64
#  16  pcv     101 non-null    object
#  17  wc      92 non-null     float64
#  18  rc      83 non-null     float64
#  19  htn     119 non-null    object
#  20  dm      119 non-null    object
#  21  cad     119 non-null    object
#  22  appet   119 non-null    object
#  23  pe      119 non-null    object
#  24  ane     119 non-null    object
# dtypes: float64(13), int64(1), object(11)
# memory usage: 23.6+ KB

# %%
print(df.nunique())
# Out:
# id       120
# age       53
# bp         7
# sg         5
# al         5
# su         6
# rbc        2
# pc         2
# pcc        2
# ba         2
# bgr       72
# bu        66
# sc        43
# sod       24
# pot       30
# hemo      71
# pcv       36
# wc        53
# rc        35
# htn        2
# dm         3
# cad        2
# appet      2
# pe         2
# ane        2
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# id        0
# age       4
# bp        3
# sg       11
# al       11
# su       11
# rbc      45
# pc       15
# pcc       0
# ba        0
# bgr      11
# bu        5
# sc        5
# sod      20
# pot      20
# hemo     13
# pcv      19
# wc       28
# rc       37
# htn       1
# dm        1
# cad       1
# appet     1
# pe        1
# ane       1
# dtype: int64

# %%
df.dtypes
# Out:
# id         int64
# age      float64
# bp       float64
# sg       float64
# al       float64
# su       float64
# rbc       object
# pc        object
# pcc       object
# ba        object
# bgr      float64
# bu       float64
# sc       float64
# sod      float64
# pot      float64
# hemo     float64
# pcv       object
# wc       float64
# rc       float64
# htn       object
# dm        object
# cad       object
# appet     object
# pe        object
# ane       object
# dtype: object

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
Data Cleaning

# %%
df.isnull().mean().plot.bar(figsize=(10,6))
plt.ylabel('Percentage of missing values')
plt.xlabel('Features')
plt.title('Missing Data in Percentages');

# %%
for column in df.select_dtypes(include=['number']):
    df[column] = df[column].fillna(df[column].mean())

df
# Out:
#       id   age     bp        sg   al        su       rbc        pc  \
# 0    209  19.0   70.0  1.020000  0.0  0.000000       NaN    normal
# 1    280  47.0   80.0  1.017339  1.0  0.477064       NaN       NaN
# 2     33  60.0  100.0  1.020000  2.0  0.000000  abnormal  abnormal
# 3    210  59.0  100.0  1.015000  4.0  2.000000    normal    normal
# 4     93  73.0  100.0  1.010000  3.0  2.000000  abnormal  abnormal
# ..   ...   ...    ...       ...  ...       ...       ...       ...
# 115   60  67.0   90.0  1.020000  1.0  0.000000       NaN  abnormal
# 116   79  56.0   80.0  1.010000  1.0  0.000000       NaN    normal
# 117  285  66.0   70.0  1.020000  0.0  0.000000    normal    normal
# 118  305  41.0   80.0  1.020000  0.0  0.000000    normal    normal
# 119  281  55.0   80.0  1.025000  0.0  0.000000    normal    normal
#
#             pcc          ba  ...       hemo  pcv            wc        rc  htn  \
# 0    notpresent  notpresent  ...  11.500000  NaN   6900.000000  4.709639   no
# 1    notpresent  notpresent  ...  13.300000   52   8100.000000  5.200000   no
# 2    notpresent  notpresent  ...  10.100000   29   8518.478261  4.709639  yes
# 3    notpresent  notpresent  ...   7.300000   20   9800.000000  3.900000  yes
# 4       present  notpresent  ...   9.200000   30   7000.000000  3.200000  yes
# ..          ...         ...  ...        ...  ...           ...       ...  ...
# 115     present  notpresent  ...  12.514953  NaN   8518.478261  4.709639  yes
# 116  notpresent  notpresent  ...  13.500000   40  11800.000000  5.000000  yes
# 117  notpresent  notpresent  ...  16.000000   41   5300.000000  5.900000   no
# 118  notpresent  notpresent  ...  17.100000   41   9100.000000  5.200000   no
# 119  notpresent  notpresent  ...  15.500000   41   9100.000000  6.000000   no
#
#       dm  cad  appet   pe  ane
# 0     no   no   good   no   no
# 1     no   no   good   no   no
# 2     no   no   poor   no   no
# 3    yes  yes   good   no  yes
# 4    yes  yes   poor   no   no
# ..   ...  ...    ...  ...  ...
# 115   no   no   good   no   no
# 116  yes   no   poor  yes   no
# 117   no   no   good   no   no
# 118   no   no   good   no   no
# 119   no   no   good   no   no
#
# [120 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# id        0
# age       0
# bp        0
# sg        0
# al        0
# su        0
# rbc      45
# pc       15
# pcc       0
# ba        0
# bgr       0
# bu        0
# sc        0
# sod       0
# pot       0
# hemo      0
# pcv      19
# wc        0
# rc        0
# htn       1
# dm        1
# cad       1
# appet     1
# pe        1
# ane       1
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
Data Transformation

# %%
non_numeric_columns = df.select_dtypes(exclude=['number']).columns

df_encoded = pd.get_dummies(df, columns=non_numeric_columns)

scaler = StandardScaler()
X = scaler.fit_transform(df_encoded.select_dtypes(include=['number']))
X
# Out:
# array([[ 1.41971300e-01, -2.01597347e+00, -6.16972401e-01, ...,
#         -3.60849974e-01, -7.24955093e-01, -1.05067398e-15],
#        [ 7.17969145e-01, -2.81894595e-01,  2.12749104e-01, ...,
#          2.79110477e-01, -1.87446414e-01,  5.80074906e-01],
#        [-1.28585434e+00,  5.23213453e-01,  1.87219211e+00, ...,
#         -8.58596992e-01,  0.00000000e+00, -1.05067398e-15],
#        ...,
#        [ 7.58532373e-01,  8.94801783e-01, -6.16972401e-01, ...,
#          1.23905115e+00, -1.44163333e+00,  1.40814252e+00],
#        [ 9.20785287e-01, -6.53482925e-01,  2.12749104e-01, ...,
#          1.63013810e+00,  2.60477485e-01,  5.80074906e-01],
#        [ 7.26081790e-01,  2.13556512e-01,  2.12749104e-01, ...,
#          1.06128436e+00,  2.60477485e-01,  1.52643790e+00]])
